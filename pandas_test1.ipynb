# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',header=None)

# %%
df.shape
# Out:
# (32561, 15)

# %%
df_half_rows = df.drop([1,2,3], axis= 1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32561, step=1)

# %%
df.shape[1]
# Out:
# 15

# %%
df_half_rows
# Out:
#        0   4                    5                   6               7   \
# 0      39  13        Never-married        Adm-clerical   Not-in-family
# 1      50  13   Married-civ-spouse     Exec-managerial         Husband
# 2      38   9             Divorced   Handlers-cleaners   Not-in-family
# 3      53   7   Married-civ-spouse   Handlers-cleaners         Husband
# 4      28  13   Married-civ-spouse      Prof-specialty            Wife
# ...    ..  ..                  ...                 ...             ...
# 32556  27  12   Married-civ-spouse        Tech-support            Wife
# 32557  40   9   Married-civ-spouse   Machine-op-inspct         Husband
# 32558  58   9              Widowed        Adm-clerical       Unmarried
# 32559  22   9        Never-married        Adm-clerical       Own-child
# 32560  52   9   Married-civ-spouse     Exec-managerial            Wife
#
#            8        9      10  11  12              13      14
# ...

# %%
df[1:5, axis=1]
# Out:
#   File "<ipython-input-41-0d46b50fced8>", line 1
#     df[1:5, axis=1]
#                 ^
# SyntaxError: invalid syntax

# %%
df.shape
# Out:
# (32561, 15)

# %%
df['gender'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/curso_python/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'gender'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-39959e69cfad> in <module>
# ----> 1 df['gender'].value_counts()
#
# ...
